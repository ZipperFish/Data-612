# %% [markdown]
# # Reseach Discussion Assignment 2

# %% [markdown]
# In "Music Recommendations at Scale with Spark", speaker " Christopher Johnson" discuss recommendations systems process implementated in Spotify system. Spotify has 40 milliion songs and to recommend songs to users some systems used are manual curation, tagging attributes, audion analysis, and collaborative filtering. tagging attributes is an entensive process as musicians will have to scale  large volumes of songs to recommend songs  and collaborative filtering allows to find relationships bewteen what similar users may enjoy.
# Explicit Matrix Factorizing  approaches the problem of how users will rate movies that they not seen yet, based on the factors of how other users interact with that movie. Spotify uses an implicit matrix factorization where we can observe what will enjoy based on their previous listens. To undersand how users will rate these songs we use the Alternating Least Square Methods by fixing  item and user vectors for their least squre regression to find a find a convergence.
# Hadoop uses blocks for a subset of users and songs and uses item vectors associated with the block and solve optimal user vetors.
# Hadoop uses multiple disk to read for each read during the iteration, however Sparks solve this problems through memory caching which solve the input and output bootleneck.
# In their first attempt, their prolems shuffling data across each iteration which  takes a long time to process. The second  attempt known as full griddy spilts the data into blocks decrease shuffuling and improving the caching, which only send necessary items blocks to each block. The third attempt or half griddy uses every rating from blocks to cut down the ratings which increase the amount of users in each block, however this takes more memmory for this process.
